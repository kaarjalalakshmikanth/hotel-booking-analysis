# %% [markdown]
# ---
#
# # <center> Hotel_bookings project </center>
#
# ---

# %% [markdown]
# ![gordon-website-imagess-02.jpg](attachment:gordon-website-imagess-02.jpg)

# %% [markdown]
# # Problem Statement and Context:
#
# **This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things.**

# %% [markdown]
# ### Visual inspection of data
# * Data have 32 columns (variables).
# * There are 119390 rows (observations).
# * Data have some missing informations
# ### Data Dictionary
#
# * hotel	Type of hotel: (Resort Hotel, City Hotel)
# * is_canceled :	Reservation cancellation status(YES,NO)
# * lead_time: Number of days between booking and arrival
# * arrival_date_year : Year of arrival
# * arrival_date_month: Month of arrival
# * arrival_date_week_number : Week number of the year for arrival
# * arrival_date_day_of_month : Day of the month of arrival
# * stays_in_weekend_nights: Number of weekend nights (Saturday and Sunday) the guest stayed or booked
# * stays_in_week_nights : Number of week nights the guest stayed or booked
# * adults : Number of adults
# * children : Number of children
# * babies : Number of babies
# * meal : Type of meal booked (BB, FB, HB, SC, Undefined)
# * country :	Country of origin of the guest
# * market_segment : Market segment designation
# * distribution_channel :Booking distribution channel
# * is_repeated_guest : If the guest is a repeat customer (YES,NO)
# * previous_cancellations : Number of previous bookings that were canceled by the customer
# * previous_bookings_not_canceled : Number of previous bookings that were not canceled by the customer
# * reserved_room_type :	Type of reserved room
# * assigned_room_type :	Type of assigned room
# * booking_changes :	Number of changes made to the booking
# * deposit_type : Type of deposit made (No Deposit, Refundable, Non Refund)
# * agent : ID of the travel agent responsible for the booking
# * company :	ID of the company responsible for the booking
# * days_in_waiting_list : Number of days the booking was in the waiting list
# * customer_type	: Type of customer (Transient, Contract, Transient-Party, Group)
# * adr :	Average Daily Rate
# * required_car_parking_spaces :	Number of car parking spaces required
# * total_of_special_requests	: Number of special requests made
# * reservation_status : Last reservation status (Check-Out, Canceled, No-Show)
# * reservation_status_date :	Date of the last reservation status
# * name	Guest's: name
# * email	Guest's: email address
# * phone-number : Guest's phone number
# * credit_card : Last four digits of the guest's credit card

# %% [markdown]
# ## Importing necessary libraries
# We will import required packages for the analysis.

# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd
# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data importing
# Here we will import abtest xls data.

# %%
df=pd.read_csv("E:/project_k/hotel_bookings.csv")

# %% [markdown]
# ## Data Overview and understanding

# %% [markdown]
# We will check structure and summary of data befor data analysis.

# %%
# Checking fist five observations of data with head
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# checking last five observations of data with head
df.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Converting flot to string

# %%
df['is_canceled'] = df['is_canceled'].replace({0: 'No', 1: 'Yes'}) # this column name is is_canceled.

# %%
df['is_canceled'] = df['is_canceled'].astype(str)

# %%
df['is_repeated_guest'] = df['is_repeated_guest'].replace({0: 'No', 1: 'Yes'})

# %%
df['is_repeated_guest'] = df['is_repeated_guest'].astype(str)

# %% [markdown]
# * is_canceled and is_repeated_guest columns converting flot to string.

# %%
df.head()
# Out:
#           hotel is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel          No        342               2015               July
# 1  Resort Hotel          No        737               2015               July
# 2  Resort Hotel          No          7               2015               July
# 3  Resort Hotel          No         13               2015               July
# 4  Resort Hotel          No         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Column names
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Understanding of data attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  object
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# **Observations:**

# %% [markdown]
# ## Descriptive statistics of numeric data

# %%
# descriptive details of numeric data
df.describe().T
# Out:
#                                    count         mean         std      min  \
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# previous_cancellations          119390.0     0.087118    0.844336     0.00
# previous_bookings_not_canceled  119390.0     0.137097    1.497437     0.00
# ...

# %% [markdown]
# **Observations:**
# * The lead time has a mean of 104011416, a standard deviation of 108883097, and a minimum value of 0. The 25th percentile is 18, the 50th percentile is 737, and the 75th percentile is 89000.
# * The arrival_date_year has a mean of 2016.156554, a standard deviation of 0.707476, and a minimum value of 2015.0. The 25th percentile is 2016.0, the 50th percentile is 2016.0, and the 75th percentile is 2017.0.
# * The arrival_date_week_number has a mean of 27.1661/3, a standard deviation of 13.605138, and a minimum value of 16.00. The 25th percentile is 16.00, the 50th percentile is 28.00, and the 75th percentile is 38.0.
# * The arrival_date_day_of_month has a mean of 15.796241, a standard deviation of 8.780829, and a minimum value of 1.00. The 25th percentile is 8.00, the 50th percentile is 16.00, and the 75th percentile is 23.0.
# * The stays_in_weekend_nights has a mean of 0.927599, a standard deviation of 0.996613, and a minimum value of 0.00. The 25th percentile is 0.00, the 50th percentile is 1.00, and the 75th percentile is 2.0.
# * The stays_in_week_nights has a mean of 2.600302, a standard deviation of 1.908286, and a minimum value of 0.00. The 25th percentile is 1.00, the 50th percentile is 2.00, and the 75th percentile is 4.00.
# * The adults has a mean of 1.858403, a standard deviation of 0.579261, and a minimum value of 0.00. The 25th percentile is 1.00, the 50th percentile is 2.00, and the 75th percentile is 2.00.
# * The children has a mean of 0.103890, a standard deviation of 0.396561, and a minimum value of 0.00. The 25th percentile is 0.00, the 50th percentile is 0.00, and the 75th percentile is 0.00.
# * The babies has a mean of 0.007549, a standard deviation of 0.097436, and a minimum value of 0.00. The 25th percentile is 0.00, the 50th percentile is 0.00, and the 75th percentile is 0.00.
# * The previous_cancellations has a mean of 0.087118, a standard deviation of 0.844336, and a minimum value of 0.00. The 25th percentile is 0.00, the 50th percentile is 0.00, and the 75th percentile is 0.00.
# * The previous_bookings_not_canceled has a mean of 0.137097, a standard deviation of 1.497437, and a minimum value of 0.00. The 25th percentile is 0.00, the 50th percentile is 0.00, and the 75th percentile is 0.00.
# * The booking_changes has a mean of 0.221124, a standard deviation of 0.65230

# %% [markdown]
# ##  Number of unique values

# %%
# checking the number of unique values in each column of the dataframe
df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %% [markdown]
# **Observations**
# * The is_canceled has 2 unique values - "Yes" and "No"
# * The customer_type column has 4 unique values.

# %% [markdown]
# ## Missing value

# %%
# checking the number of missing values in each column of the dataframe
df.isnull().sum().sort_values(ascending=True)
# Out:
# hotel                                  0
# total_of_special_requests              0
# required_car_parking_spaces            0
# adr                                    0
# customer_type                          0
# days_in_waiting_list                   0
# deposit_type                           0
# booking_changes                        0
# assigned_room_type                     0
# reserved_room_type                     0
# previous_bookings_not_canceled         0
# previous_cancellations                 0
# is_repeated_guest                      0
# reservation_status                     0
# distribution_channel                   0
# reservation_status_date                0
# meal                                   0
# babies                                 0
# adults                                 0
# stays_in_week_nights                   0
# stays_in_weekend_nights                0
# arrival_date_day_of_month              0
# market_segment                         0
# ...

# %% [markdown]
# **Observations**
# * company column is more then 80% missing values there.
# * age column is no good for data.
# * children and country columns is just simple values missing.
# * children is just 4 columns and country is 488 columns missing.

# %% [markdown]
# ### Drop the missing values column.

# %%
df=df.drop(['agent','company'],axis=1) # this two column removed

# %% [markdown]
# **Observations**
# * company column is more then 80% missing values there.That reason i am drop the company column.
# * Agent column is not good data for analysing. That reason i am drop the agent column also.
# * Now i am 2 columns drop.

# %%
df=df.dropna(axis = 0)

# %% [markdown]
# **Observations**
# * country and childran columns is littie bit missing values there. that reason remove the some missing values.

# %% [markdown]
# ### Missing values cleaning after cheching data

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# days_in_waiting_list              0
# customer_type                     0
# adr                               0
# ...

# %% [markdown]
# # After cleaning data

# %%
df.to_csv('Hotel_data_KL.csv', index=False)   # download hotel_data

# %%
df.shape     # how many rows and columns
# Out:
# (118898, 30)

# %%
df.describe(include='object')  # count, unique, top and frequency for the object columns.
# Out:
#              hotel is_canceled arrival_date_month    meal country  \
# count       118898      118898             118898  118898  118898
# unique           2           2                 12       5     177
# top     City Hotel          No             August      BB     PRT
# freq         79302       74745              13852   91863   48586
#
#        market_segment distribution_channel is_repeated_guest  \
# count          118898               118898            118898
# unique              7                    5                 2
# top         Online TA                TA/TO                No
# freq            56402                97730            115092
#
#        reserved_room_type assigned_room_type deposit_type customer_type  \
# count              118898             118898       118898        118898
# unique                 10                 12            3             4
# top                     A                  A   No Deposit     Transient
# ...

# %%
## Grouping arrival_date_year, arrival_date_month, arrival_date_day_of_month to date
df['Arrival Date'] = df['arrival_date_year'].astype(str) + '-' + df['arrival_date_month'].astype(str) + '-' + df['arrival_date_day_of_month'].astype(str)
df['Arrival Date'].head()
# Out:
# 0    2015-July-1
# 1    2015-July-1
# 2    2015-July-1
# 3    2015-July-1
# 4    2015-July-1
# Name: Arrival Date, dtype: object

# %%
#Categorical Column
cat_cols=[i for i in df.columns if df.dtypes[i]=='object']
print('Categorical columns : {}'.format(len(cat_cols)))
print(cat_cols)

print('-'*65)

#Numeric Column
num_cols = [i for i in df.columns if df.dtypes[i]==('int64') or df.dtypes[i]==('float64')]
print('Numerical columns : {}'.format(len(num_cols)))
print(num_cols)

# print(len(data.columns))
# Out:
# Categorical columns : 14
# ['hotel', 'is_canceled', 'arrival_date_month', 'meal', 'country', 'market_segment', 'distribution_channel', 'is_repeated_guest', 'reserved_room_type', 'assigned_room_type', 'deposit_type', 'customer_type', 'reservation_status', 'reservation_status_date']
# -----------------------------------------------------------------
# Numerical columns : 16
# ['lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']

# %% [markdown]
# ---
#
# **Before we further process the data, let's have a look at the graphical visualization of the data to understand it in a better way!**
#
# ---

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# - EDA is an important part of any project involving data.
# - It is important to investigate and understand the data better before building a model with it.
# - A few questions have been mentioned below which will help you approach the analysis in the right manner and generate insights from the data.
# - A thorough analysis of the data, in addition to the questions mentioned below, should be done.

# %%
# Grouping data by 'arrival_date_month' and calculating cancellation rate
cancellation_rate_by_month = df.groupby('arrival_date_month')['is_canceled'].count().reset_index()

# Sorting the months in the correct order
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
cancellation_rate_by_month['arrival_date_month'] = pd.Categorical(cancellation_rate_by_month['arrival_date_month'], categories=month_order, ordered=True)
cancellation_rate_by_month = cancellation_rate_by_month.sort_values('arrival_date_month')

# Plotting the results
plt.figure(figsize=(12, 6))
sns.barplot(x='is_canceled', y='arrival_date_month', data=cancellation_rate_by_month, palette='viridis')
plt.title('Cancellation Rate by Month')
plt.xlabel('Month')
plt.ylabel('Cancellation Rate')
plt.show()

# %%
# Calculating the percentage of each class
percentage = df['is_canceled'].value_counts(normalize=True) * 100

# Plotting the percentage of each class
plt.figure(figsize=(8, 5))
ax = sns.barplot(x=percentage.index, y=percentage, palette=['darkturquoise', 'royalblue'])
plt.title('Percentage of Cancellations and Non-Cancellations')
plt.xlabel('Is Canceled')
plt.ylabel('Percentage (%)')
plt.xticks(ticks=[0, 1], labels=['Not Canceled', 'Canceled'])
plt.yticks(ticks=range(0,80,10))

# Displaying the percentage on the bars
for i, p in enumerate(percentage):
    ax.text(i, p + 0.5, f'{p:.2f}%', ha='center', va='bottom')

plt.show()

# %% [markdown]
# # conclustion
# * The percentage of cancellations is higher than the percentage of non-cancellations. 62.96% of the items were cancelled, while only 37.04% were not cancelled.
# * This suggests that there is a problem with the product or service that is causing customers to cancel their orders.
# * It is important to investigate the reasons for the cancellations and take steps to address them.

# %%
#### ====== VISUALISASI DATA ========
#### Univariate

##== lead_time (days)
# data['lead_time'].describe()
df['lead_time_30'] = df['lead_time']//30 #convert to month
# data['lead_time_30'].describe()

##Visualisasi Data
plt.figure(figsize=(10,6))
sns.countplot(x=df['lead_time_30'], palette='RdYlBu')
plt.show()

#Interpretasi:
#banyak customers yang waktu antara booking hotel dengan tanggal kedatangan (arrival date) kurang dari 1 bulan

# %% [markdown]
# **conclustion:-**
# * The highest bar is at 30 minutes, which means that there were more lead times of 30 minutes than any other duration.

# %% [markdown]
# ## 1.What types of bookings are most likely to be cancelled?

# %%
cancelled = df['is_canceled'].value_counts(normalize=True)
print(cancelled)


plt.figure(figsize =(5,4))
plt.title('Reservation status count')
plt.bar(['Not Cancelled' , 'Cancelled'],df['is_canceled'].value_counts(),width = 0.7,edgecolor ='k')
plt.show()
# Out:
# is_canceled
# No     0.628648
# Yes    0.371352
# Name: proportion, dtype: float64

# %% [markdown]
# **Observations**
# * There are far more reservations that are not canceled than reservations that are canceled.
# * The number of reservations that are not canceled is 62,468.
# * The number of reservations that are canceled is 7,532.
# * This means that 89.4% of reservations are not canceled, and 10.6% of reservations are canceled.

# %%
plt.figure(figsize=(8, 4))
ax1 = sns.countplot(x='hotel', hue='is_canceled', data=df, palette='Blues')

# Explicitly create a legend after removing the original one
ax1.get_legend().remove()
ax1.legend(title='is_canceled', bbox_to_anchor=(1, 1))

plt.xlabel('hotel')
plt.ylabel('Number of reservations')
plt.title('Reservation in different hotels', size=20)
plt.show()

# %%
# Count Hotel
hotel_count = df.hotel.value_counts()

# Plotting Values in a simple pie chart
hotel_count.plot.pie(figsize=(9,7), autopct='%1.2f%%', shadow=True, fontsize=15,startangle=50)
# Setting the title
plt.title('Hotel Booking Percentage')
plt.axis('equal')
plt.show()

# %%
# Calculate cancellation rates for each category
cancellation_rates = df.groupby('hotel')['is_canceled'].count().reset_index()

# Display the cancellation rates
print("Cancellation rates by hotel type:")
print(cancellation_rates)
# Out:
# Cancellation rates by hotel type:
#           hotel  is_canceled
# 0    City Hotel        79302
# 1  Resort Hotel        39596

# %% [markdown]
# # What types of guests are most likely to stay at our hotels

# %%
# Analyzing guest types based on 'customer_type'
customer_type_counts = df['customer_type'].value_counts()

# Plotting the distribution of customer types
plt.figure(figsize=(8, 6))
sns.barplot(x=customer_type_counts.index, y=customer_type_counts.values, palette='viridis')
plt.title('Distribution of Customer Types')
plt.xlabel('Customer Type')
plt.ylabel('Number of Guests')
plt.show()

# %%
plt.figure(figsize=(15,6))

sns.countplot(data = df, x = 'arrival_date_year', hue='hotel', palette='Paired')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='arrival_date_year', y='lead_time',hue='is_canceled', data= df, palette='vlag')
plt.title('Arriving year, Leadtime and Cancelations')
plt.show()

# %%
# Group data by 'arrival_date_month' and calculate cancellation rate
cancellation_by_month = df.groupby('arrival_date_month')['is_canceled'].count()

# Plot the cancellation rate over months
plt.figure(figsize=(10, 6))
cancellation_by_month.plot(kind='bar', color='skyblue')
plt.title('Cancellation Rate by Month')
plt.xlabel('Month')
plt.ylabel('Cancellation Rate')
plt.xticks(rotation=45)
plt.show()

# %%
# Previous cancellations vs. Booking Cancellation
sns.countplot(x='previous_cancellations', hue='is_canceled', data=df)
plt.title('Previous Cancellations vs. Booking Cancellation')
plt.show()

# %%
# Special requests vs. Booking Cancellation
sns.countplot(x='total_of_special_requests', hue='is_canceled', data=df)
plt.title('Special Requests vs. Booking Cancellation')
plt.show()

# %%
# the success rate for different meal types, for example
sns.countplot(x='meal', hue='is_canceled', data=df)
plt.title('Meal Type vs. Booking Cancellation')
plt.show()

# %%
# Visualize the correlation between lead time, booking changes, and reservation status
sns.scatterplot(x='lead_time', y='booking_changes', hue='reservation_status', data=df)
plt.title('Lead Time vs. Booking Changes')
plt.xlabel('Lead Time')
plt.ylabel('Booking Changes')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='hotel', y='stays_in_weekend_nights')
plt.title('Stays in Weekend Nights for Different Types of Hotels')
plt.xlabel('Hotel Type')
plt.ylabel('Stays in Weekend Nights')
plt.show()

# %%
sns.countplot(data = df, x = 'arrival_date_month')
plt.title('Arrivals per month',fontweight="bold", size=15)
plt.subplots_adjust(right=1.5)

plt.show()

# %%
sns.countplot(data = df, x = 'stays_in_weekend_nights', hue='is_canceled', palette='rocket')
plt.title('WeekendStay vs Cancelation',fontweight="bold", size=20)
plt.subplots_adjust(right=1.7)
plt.show()

# %% [markdown]
# The number of cancellations is relatively low. This suggests that people are generally happy with their weekend stays and are not likely to cancel them.
# There is a peak in the number of weekend stays around stay number 7. This suggests that there may be a popular length of stay for weekend getaways.
# There is a peak in the number of cancellations around stay number 10. This suggests that there may be a common reason for people to cancel weekend stays after this point.

# %% [markdown]
# # END
